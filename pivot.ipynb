# %%
import pandas as pd

# %%
df = pd.read_csv("file.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#    CustomerID Gender Location  Tenure_Months  Transaction_ID Transaction_Date  \
# 0     17850.0      M  Chicago           12.0         16679.0       2019-01-01
# 1     17850.0      M  Chicago           12.0         16680.0       2019-01-01
# 2     17850.0      M  Chicago           12.0         16696.0       2019-01-01
# 3     17850.0      M  Chicago           12.0         16699.0       2019-01-01
# 4     17850.0      M  Chicago           12.0         16700.0       2019-01-01
#
#       Product_SKU                                Product_Description  \
# 0  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 1  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
# 2  GGOENEBQ078999             Nest Cam Outdoor Security Camera - USA
# 3  GGOENEBQ079099    Nest Protect Smoke + CO White Battery Alarm-USA
# 4  GGOENEBJ079499  Nest Learning Thermostat 3rd Gen-USA - Stainle...
#
#   Product_Category  Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST  \
# 0         Nest-USA       1.0     153.71               6.5          Used  0.1
# 1         Nest-USA       1.0     153.71               6.5          Used  0.1
# 2         Nest-USA       2.0     122.77               6.5      Not Used  0.1
# 3         Nest-USA       1.0      81.50               6.5       Clicked  0.1
# 4         Nest-USA       1.0     153.71               6.5       Clicked  0.1
#
#        Date  Offline_Spend  Online_Spend  Month Coupon_Code  Discount_pct
# 0  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 1  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 2  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 3  1/1/2019         4500.0        2424.5      1      ELEC10          10.0
# 4  1/1/2019         4500.0        2424.5      1      ELEC10          10.0

# %%
df2 = df.drop(["CustomerID", "Coupon_Code", "Product_Description", "Transaction_ID", "Product_SKU"], axis=1)
df2
# Out:
#       Gender Location  Tenure_Months Transaction_Date      Product_Category  \
# 0          M  Chicago           12.0       2019-01-01              Nest-USA
# 1          M  Chicago           12.0       2019-01-01              Nest-USA
# 2          M  Chicago           12.0       2019-01-01              Nest-USA
# 3          M  Chicago           12.0       2019-01-01              Nest-USA
# 4          M  Chicago           12.0       2019-01-01              Nest-USA
# ...      ...      ...            ...              ...                   ...
# 52950    NaN      NaN            NaN              NaN            Gift Cards
# 52951    NaN      NaN            NaN              NaN  Notebooks & Journals
# 52952    NaN      NaN            NaN              NaN               Android
# 52953    NaN      NaN            NaN              NaN               Android
# 52954    NaN      NaN            NaN              NaN               Android
#
#        Quantity  Avg_Price  Delivery_Charges Coupon_Status  GST      Date  \
# 0           1.0     153.71               6.5          Used  0.1  1/1/2019
# 1           1.0     153.71               6.5          Used  0.1  1/1/2019
# 2           2.0     122.77               6.5      Not Used  0.1  1/1/2019
# 3           1.0      81.50               6.5       Clicked  0.1  1/1/2019
# 4           1.0     153.71               6.5       Clicked  0.1  1/1/2019
# ...         ...        ...               ...           ...  ...       ...
# 52950       NaN        NaN               NaN           NaN  NaN       NaN
# 52951       NaN        NaN               NaN           NaN  NaN       NaN
# 52952       NaN        NaN               NaN           NaN  NaN       NaN
# 52953       NaN        NaN               NaN           NaN  NaN       NaN
# 52954       NaN        NaN               NaN           NaN  NaN       NaN
#
#        Offline_Spend  Online_Spend  Month  Discount_pct
# 0             4500.0        2424.5      1          10.0
# 1             4500.0        2424.5      1          10.0
# 2             4500.0        2424.5      1          10.0
# 3             4500.0        2424.5      1          10.0
# 4             4500.0        2424.5      1          10.0
# ...              ...           ...    ...           ...
# 52950            NaN           NaN     11          20.0
# 52951            NaN           NaN     11          20.0
# 52952            NaN           NaN     10          10.0
# 52953            NaN           NaN     11          20.0
# 52954            NaN           NaN     12          30.0
#
# [52955 rows x 15 columns]

# %%
df3 = df2.dropna()
df3
# Out:
#       Gender    Location  Tenure_Months Transaction_Date  \
# 0          M     Chicago           12.0       2019-01-01
# 1          M     Chicago           12.0       2019-01-01
# 2          M     Chicago           12.0       2019-01-01
# 3          M     Chicago           12.0       2019-01-01
# 4          M     Chicago           12.0       2019-01-01
# ...      ...         ...            ...              ...
# 52919      F  California            8.0       2019-03-10
# 52920      M     Chicago           34.0       2019-03-28
# 52921      M  California           15.0       2019-10-06
# 52922      M  California           15.0       2019-10-06
# 52923      F     Chicago            8.0       2019-10-06
#
#            Product_Category  Quantity  Avg_Price  Delivery_Charges  \
# 0                  Nest-USA       1.0     153.71               6.5
# 1                  Nest-USA       1.0     153.71               6.5
# 2                  Nest-USA       2.0     122.77               6.5
# 3                  Nest-USA       1.0      81.50               6.5
# 4                  Nest-USA       1.0     153.71               6.5
# ...                     ...       ...        ...               ...
# 52919            Gift Cards       1.0     250.00               0.0
# 52920            Gift Cards       1.0      25.00               0.0
# 52921  Notebooks & Journals       1.0      10.80               6.0
# 52922  Notebooks & Journals       1.0       9.60               6.0
# 52923  Notebooks & Journals       1.0       5.59               6.5
#
#       Coupon_Status   GST       Date  Offline_Spend  Online_Spend  Month  \
# 0              Used  0.10   1/1/2019         4500.0       2424.50      1
# 1              Used  0.10   1/1/2019         4500.0       2424.50      1
# 2          Not Used  0.10   1/1/2019         4500.0       2424.50      1
# 3           Clicked  0.10   1/1/2019         4500.0       2424.50      1
# 4           Clicked  0.10   1/1/2019         4500.0       2424.50      1
# ...             ...   ...        ...            ...           ...    ...
# 52919       Clicked  0.05  3/10/2019         2500.0       1294.22      3
# 52920          Used  0.05  3/28/2019         2000.0       1066.12      3
# 52921       Clicked  0.05  10/6/2019         3000.0       2230.76     10
# 52922          Used  0.05  10/6/2019         3000.0       2230.76     10
# 52923      Not Used  0.05  10/6/2019         3000.0       2230.76     10
#
#        Discount_pct
# 0              10.0
# 1              10.0
# 2              10.0
# 3              10.0
# 4              10.0
# ...             ...
# 52919          30.0
# 52920          30.0
# 52921          10.0
# 52922          10.0
# 52923          10.0
#
# [52524 rows x 15 columns]

# %%
df3['Transaction_Date'] = pd.to_datetime(df3['Transaction_Date'])
df3['Date'] = pd.to_datetime(df3['Date'])
# Out:
# C:\Users\userr\AppData\Local\Temp\ipykernel_25564\3118525459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Transaction_Date'] = pd.to_datetime(df3['Transaction_Date'])
# C:\Users\userr\AppData\Local\Temp\ipykernel_25564\3118525459.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Date'] = pd.to_datetime(df3['Date'])

# %%
from pivottablejs import pivot_ui
def pivot_ui(df, **kwargs):
    import pivottablejs
    class _DataFrame(pd.DataFrame):
        def to_csv(self, **kwargs):
            return super().to_csv(**kwargs).replace("\r\n", "\n")
    return pivottablejs.pivot_ui(_DataFrame(df), **kwargs)

pivot_ui(df3)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
